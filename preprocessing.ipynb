# %% [markdown]
# # Preprocessing
#
# This notebook is dedicated to the preprocessing steps necessary for our data analysis and modeling. Key activities include:
#
# 1. **Data Loading**: Importing the dataset into the notebook.
# 2. **Data Extension**: Augmenting the dataset with additional statistics to provide more comprehensive insights.
# 3. **Summary Tables and Plots Generation**: Creating visualizations and tables to summarize the data, which aids in understanding the distribution, trends, and relationships within the dataset.
# 4. **Normalization**: Standardizing the data to bring all variables into a comparable range, crucial for ensuring fair weighting in modeling.
# 5. **Feature Selection**: Identifying and selecting the most significant features for the models, enhancing model performance and interpretability.

# %%
import pandas as pd
from code.preprocessing.stats import add_net_avg_shooting_pct, add_true_shooting_percentage

# Read the data from the CSV file
df = pd.read_csv('./data/shooting_stats.csv')

df = add_net_avg_shooting_pct(df)
df = add_true_shooting_percentage(df)

# Save the extended DataFrame to a new CSV file
df.to_csv('./data/shooting_stats_extended.csv', index=False)

# %%
from code.preprocessing.vis import generate_summary_table, plot_shooting_summary

plot_shooting_summary()
generate_summary_table()
# Out:
#                     three_pct_season  lwr_paint_pct_oct_nov  \
# Summary Statistics
# count                     108.000000             108.000000
# mean                        0.361176               0.575398
# std                         0.039623               0.083720
# min                         0.220000               0.278000
# 25%                         0.337000               0.514000
# 50%                         0.366500               0.578500
# 75%                         0.387250               0.625750
# max                         0.437000               0.800000
#
#                     upr_paint_pct_oct_nov  mid_pct_oct_nov  \
# Summary Statistics
# count                          108.000000       108.000000
# mean                             0.435944         0.407519
# std                              0.091394         0.121003
# min                              0.167000         0.000000
# 25%                              0.388250         0.330000
# 50%                              0.444000         0.402500
# 75%                              0.488750         0.477250
# max                              0.692000         0.900000
#
#                     three_non_cnr_pct_oct_nov  three_cnr_pct_oct_nov  \
# Summary Statistics
# count                              108.000000             108.000000
# mean                                 0.366417               0.355046
# std                                  0.088564               0.068755
# min                                  0.150000               0.167000
# 25%                                  0.307000               0.316000
# 50%                                  0.364000               0.359000
# 75%                                  0.426750               0.394250
# max                                  0.667000               0.500000
#
#                     ft_pct_oct_nov  lwr_paint_shots_oct_nov  \
# Summary Statistics
# count                   108.000000               108.000000
# mean                      0.801222                88.138889
# std                       0.083965                42.961939
# min                       0.500000                14.000000
# 25%                       0.741000                54.000000
# 50%                       0.811000                85.000000
# 75%                       0.868500               111.250000
# max                       1.000000               238.000000
#
#                     upr_paint_shots_oct_nov  mid_shots_oct_nov  \
# Summary Statistics
# count                            108.000000         108.000000
# mean                              40.425926          24.092593
# std                               25.618409          13.055265
# min                               10.000000          10.000000
# 25%                               23.000000          14.000000
# 50%                               34.000000          22.000000
# 75%                               50.000000          31.000000
# max                              170.000000          72.000000
#
#                     three_non_cnr_shots_oct_nov  three_cnr_shots_oct_nov  \
# Summary Statistics
# count                                108.000000               108.000000
# mean                                  39.435185                57.472222
# std                                   15.021028                28.042177
# min                                   11.000000                12.000000
# 25%                                   28.000000                35.000000
# 50%                                   40.500000                55.500000
# 75%                                   49.000000                74.250000
# max                                   82.000000               159.000000
#
#                     ft_shots_oct_nov  net_avg_pct_oct_nov  total_attempts  \
# Summary Statistics
# count                     108.000000           108.000000      108.000000
# mean                       69.425926             0.527430      318.990741
# std                        46.346965             0.056882      121.388578
# min                         7.000000             0.390333       89.000000
# 25%                        34.000000             0.487550      229.000000
# 50%                        58.000000             0.518803      301.500000
# 75%                        96.000000             0.566073      390.000000
# max                       213.000000             0.692199      644.000000
#
#                     total_points      ts_pct
# Summary Statistics
# count                 108.000000  108.000000
# mean                  322.051565    0.463324
# std                   127.026082    0.039819
# min                    86.014000    0.382245
# 25%                   232.669750    0.430731
# 50%                   304.901500    0.461959
# 75%                   389.843750    0.493546
# max                   699.066000    0.564418

# %%
from code.preprocessing.feature_selection import select_features
from code.preprocessing.vis import plot_feature_importance 

selected_features, feature_info = select_features(10)
plot_feature_importance(feature_info)
