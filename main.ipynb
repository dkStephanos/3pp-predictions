# %%
from code.preprocessing.utils import normalize_shooting_stats

df = normalize_shooting_stats()
df
# Out:
#                          Name  three_pct_season  lwr_paint_pct_oct_nov  \
# 0             Malcolm Brogdon          1.922562              -1.096806
# 1                Tyrese Maxey          1.871851              -0.844799
# 2               Stephen Curry          1.795784               1.567262
# 3    Kentavious Caldwell-Pope          1.542228              -1.096806
# 4                Jevon Carter          1.516873              -1.108806
# ..                        ...               ...                    ...
# 103            Scottie Barnes         -1.982194               0.019223
# 104             Killian Hayes         -2.058261              -3.568868
# 105     Giannis Antetokounmpo         -2.185039               1.063249
# 106                   Bol Bol         -2.362528               2.695291
# 107          Dennis Smith Jr.         -3.579595              -0.160782
#
#      upr_paint_pct_oct_nov  mid_pct_oct_nov  three_non_cnr_pct_oct_nov  \
# ...
