# %%
from code.preprocessing.stats import add_net_avg_shooting_pct, add_true_shooting_percentage

df = add_net_avg_shooting_pct()
df = add_true_shooting_percentage()

# Save the extended DataFrame to a new CSV file
df.to_csv('./data/shooting_stats_extended.csv', index=False)

# %%
from code.preprocessing.vis import summarize_and_plot

summary = summarize_and_plot()
summary
# Out:
#        three_pct_season  lwr_paint_pct_oct_nov  upr_paint_pct_oct_nov  \
# count        108.000000             108.000000             108.000000
# mean           0.361176               0.575398               0.435944
# std            0.039623               0.083720               0.091394
# min            0.220000               0.278000               0.167000
# 25%            0.337000               0.514000               0.388250
# 50%            0.366500               0.578500               0.444000
# 75%            0.387250               0.625750               0.488750
# max            0.437000               0.800000               0.692000
#
#        mid_pct_oct_nov  three_non_cnr_pct_oct_nov  three_cnr_pct_oct_nov  \
# count       108.000000                 108.000000             108.000000
# mean          0.407519                   0.366417               0.355046
# std           0.121003                   0.088564               0.068755
# min           0.000000                   0.150000               0.167000
# 25%           0.330000                   0.307000               0.316000
# 50%           0.402500                   0.364000               0.359000
# 75%           0.477250                   0.426750               0.394250
# max           0.900000                   0.667000               0.500000
#
#        ft_pct_oct_nov  lwr_paint_shots_oct_nov  upr_paint_shots_oct_nov  \
# count      108.000000               108.000000               108.000000
# mean         0.801222                88.138889                40.425926
# std          0.083965                42.961939                25.618409
# min          0.500000                14.000000                10.000000
# 25%          0.741000                54.000000                23.000000
# 50%          0.811000                85.000000                34.000000
# 75%          0.868500               111.250000                50.000000
# max          1.000000               238.000000               170.000000
#
#        mid_shots_oct_nov  three_non_cnr_shots_oct_nov  \
# count         108.000000                   108.000000
# mean           24.092593                    39.435185
# std            13.055265                    15.021028
# min            10.000000                    11.000000
# 25%            14.000000                    28.000000
# 50%            22.000000                    40.500000
# 75%            31.000000                    49.000000
# max            72.000000                    82.000000
#
#        three_cnr_shots_oct_nov  ft_shots_oct_nov  total_attempts  \
# count               108.000000        108.000000      108.000000
# mean                 57.472222         69.425926      318.990741
# std                  28.042177         46.346965      121.388578
# min                  12.000000          7.000000       89.000000
# 25%                  35.000000         34.000000      229.000000
# 50%                  55.500000         58.000000      301.500000
# 75%                  74.250000         96.000000      390.000000
# max                 159.000000        213.000000      644.000000
#
#        total_points      ts_pct
# count    108.000000  108.000000
# mean     322.051565    0.463324
# std      127.026082    0.039819
# min       86.014000    0.382245
# 25%      232.669750    0.430731
# 50%      304.901500    0.461959
# 75%      389.843750    0.493546
# max      699.066000    0.564418

# %%
from code.preprocessing.utils import normalize_shooting_stats

normalize_shooting_stats()
